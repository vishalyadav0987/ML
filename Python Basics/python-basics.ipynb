# %%
print("ML starting again from 26, Dec 2025");
# Out:
# ML starting again from 26, Dec 2025

# %% [markdown]
# #### ML Learning - 26 DEC Python Basics
# * Data types

# %%
# Adding (+)
1+1
# Out:
# 2

# %%
# Multipy (*)
2*3
# Out:
# 6

# %%
# Power (**)
2**3
# Out:
# 8

# %%
# Subtracting (-)
5-6
# Out:
# -1

# %%
# Divide (/)
5/2
# Out:
# 2.5

# %%
# Modulus (%)
10%2
# Out:
# 0

# %%
# Check Data type 
print(type(1))
print(type('vishal'))
print(type(10/3))
print(type(False))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
# Special Case
10*'xyz'
# Out:
# 'xyzxyzxyzxyzxyzxyzxyzxyzxyzxyz'

# %% [markdown]
# - Variable Assignment

# %%
# Syntax
new_varable = 10
type(new_varable)
# Out:
# int

# %%
new_string = 'ABC'
new_bool = True
new_float = 10.4
a = 10
b = 3

# %%
print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a**b)
print((a*b)+(a/b)) # It follows Bodmass rule
# Out:
# 13
# 7
# 3.3333333333333335
# 30
# 1000
# 33.333333333333336

# %% [markdown]
# - Various ways of formatting

# %%
first_name = 'Vishal'
last_name = 'Yadav'

# %%
print('My fistname is {} and last name is {}'.format(first_name,last_name)) # here squence is matter
# Out:
# My fistname is Vishal and last name is Yadav

# %%
print('My fistname is {last} and last name is {first}'.format(first=first_name,last=last_name)) # here variable matter
# Out:
# My fistname is Yadav and last name is Vishal

# %%
len(first_name+last_name)
# Out:
# 11
